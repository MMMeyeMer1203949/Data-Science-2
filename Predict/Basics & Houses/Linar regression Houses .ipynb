# %%
import pandas as pd

# %%
import seaborn as sns
#scikit-learn

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.scatterplot(data=train, x="LotFrontage", y="SalePrice", hue="YrSold")
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
train["YrSold"].unique
# Out:
# <bound method Series.unique of 0       2008
# 1       2007
# 2       2008
# 3       2006
# 4       2008
#         ...
# 1455    2007
# 1456    2010
# 1457    2010
# 1458    2010
# 1459    2008
# Name: YrSold, Length: 1460, dtype: int64>

# %%
sns.scatterplot(data=train, x="OverallQual", y="SalePrice", hue="GarageYrBlt")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.scatterplot(data=train, x="GrLivArea", y="SalePrice", hue="OverallQual")
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
train.corr() #>.6 TotalBsmtSF 1stFlrSF GarageArea  GarageCars 	         >.7 OverallQual  GrLivArea
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
sns.scatterplot(data=train, x="OverallQual", y="SalePrice", hue="GarageYrBlt")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
def trainModel(train, x , y):
    slopes = []
    for i in range(len(train)):
        slope = (train.iloc[i][SalePrice] - y) / (train.iloc[i][OverallQual] - x) #(y2-y1)/(x2-x1)
        slopes.append(slope)
    
    return sum (slopes)/len(slopes)
#b = 10000
m = trainModel(train, 0, 0)
print("y = " + str(m) + "x  + " + str(b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18984\2256644671.py in <module>
#       7     return sum (slopes)/len(slopes)
#       8 #b = 10000
# ----> 9 m = trainModel(train, 0, 0)
#      10 print("y = " + str(m) + "x  + " + str(b))
#
# ~\AppData\Local\Temp\ipykernel_18984\2256644671.py in trainModel(train, x, y)
#       2     slopes = []
#       3     for i in range(len(train)):
# ----> 4         slope = (train.iloc[i][SalePrice] - y) / (train.iloc[i][OverallQual] - x) #(y2-y1)/(x2-x1)
#       5         slopes.append(slope)
#       6
#
# NameError: name 'SalePrice' is not defined

# %%
def testModel(test, m, b):
    for i in range(len(test)):
        predicted = (m*test.iloc[i]["OverallQual"] + b)
        actual = (test.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 1000:
            check.append(1)
        else:
# Out:
#   File "C:\Users\mmeyer\AppData\Local\Temp\ipykernel_18984\25591769.py", line 9
#
#     ^
# IndentationError: expected an indented block

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(train, test_size=0.3, random_state=42)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1022 entries, 135 to 1126
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1022 non-null   int64
#  1   MSSubClass     1022 non-null   int64
#  2   MSZoning       1022 non-null   object
#  3   LotFrontage    832 non-null    float64
#  4   LotArea        1022 non-null   int64
#  5   Street         1022 non-null   object
#  6   Alley          66 non-null     object
#  7   LotShape       1022 non-null   object
#  8   LandContour    1022 non-null   object
#  9   Utilities      1022 non-null   object
#  10  LotConfig      1022 non-null   object
#  11  LandSlope      1022 non-null   object
#  12  Neighborhood   1022 non-null   object
#  13  Condition1     1022 non-null   object
#  14  Condition2     1022 non-null   object
#  15  BldgType       1022 non-null   object
#  16  HouseStyle     1022 non-null   object
# ...

# %%
def trainModel(trainDF, x, y):
    slopes = []
    for i in range(len(trainDF)):
        slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
        slopes.append(slope)
    
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(train_df, 0, 0)
print("y = " + str(m) + "x + " + str(b))
# Out:
# y = 28997.643171263946x + 10000

# %%
def testModel(testDF, m, b):
    checks = []
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["OverallQual"] + b)
        actual = (testDF.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 1000:
            checks.append(1)
        else:
            checks.append(0)
    return (checks.count(1) / len(checks)) * 100

print(testModel(test_df, m, b)) # Not great. :(
# Out:
# 2.28310502283105

# %%
if x > x x == x 

hs = 0 
if hs > x 
    hs = x
# Out:
#   File "C:\Users\mmeyer\AppData\Local\Temp\ipykernel_18984\899438945.py", line 1
#     if x > x x == x
#              ^
# SyntaxError: invalid syntax

# %%
def trainModel(trainDF, x, y):
    slopes = []
    for i in range(len(trainDF)):
        slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
        slopes.append(slope)
    
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(train_df, 0, 0)
print("y = " + str(m) + "x + " + str(b))

def testModel(testDF, m, b):
    checks = []
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["OverallQual"] + b)
        actual = (testDF.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 1000:
            checks.append(1)
        else:
            checks.append(0)
    return (checks.count(1) / len(checks)) * 100

print(testModel(test_df, m, b)) # Not great. :(
# Out:
# y = 28997.643171263946x + 10000
# 2.28310502283105

# %%
count = 0
while (count < 5000):
    count = count + 500
    def trainModel(trainDF, x, y):
        slopes = []
        for i in range(len(trainDF)):
            slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
            slopes.append(slope)

        return sum(slopes)/len(slopes)
    b = count
    m = trainModel(train_df, 0, 0)
    print("y = " + str(m) + "x + " + str(b))

    def testModel(testDF, m, b):
        checks = []
        for i in range(len(testDF)):
            predicted = (m*testDF.iloc[i]["OverallQual"] + b)
            actual = (testDF.iloc[i]["SalePrice"])
            difference = abs(predicted - actual)
            if difference <= 100000:
                checks.append(1)
            else:
                checks.append(0)
        return (checks.count(1) / len(checks)) * 100

    print(testModel(test_df, m, b)) # Not great. :(
# Out:
# y = 28997.643171263946x + 500
# 94.74885844748859
# y = 28997.643171263946x + 1000
# 94.74885844748859
# y = 28997.643171263946x + 1500
# 94.74885844748859
# y = 28997.643171263946x + 2000
# 94.74885844748859
# y = 28997.643171263946x + 2500
# 94.74885844748859
# y = 28997.643171263946x + 3000
# 94.74885844748859
# y = 28997.643171263946x + 3500
# 94.74885844748859
# y = 28997.643171263946x + 4000
# 94.74885844748859
# y = 28997.643171263946x + 4500
# 94.74885844748859
# y = 28997.643171263946x + 5000
# 94.74885844748859

# %%
# UNFINSHED 
x = 0
hs = 0
count = 0
while (count < 5000):
    count = count + 500
    def trainModel(trainDF, x, y):
        slopes = []
        for i in range(len(trainDF)):
            slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
            slopes.append(slope)

        return sum(slopes)/len(slopes)
    b = count
    m = trainModel(train_df, 0, 0)
    #print("y = " + str(m) + "x + " + str(b))

    def testModel(testDF, m, b):
        checks = []
        for i in range(len(testDF)):
            predicted = (m*testDF.iloc[i]["OverallQual"] + b)
            actual = (testDF.iloc[i]["SalePrice"])
            difference = abs(predicted - actual)
            if difference <= 1000:
                checks.append(1)
            else:
                checks.append(0)
        return (checks.count(1) / len(checks)) * 100

    x = (testModel(test_df, m, b)) # Not great. :( 
    if x > hs:
        x = hs
        
print(hs)

# add code to find the equation
# Out:
# 0

# %%
# Page Break: Mulitblle Linear Regression  
# trainDF         testDF       train
# >.7 OverallQual       GrLivAre     
#     GarageCars
# >.6 TotalBsmtSF 1stFlrSF GarageArea  GarageCars 
#
# OverallQual       GrLivAre         GarageCars
#
# SalePrice

# %%
sns.scatterplot(data=train, x="GrLivArea", y="SalePrice", hue="OverallQual")
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
def trainModel(trainDF, x, y):
    slopes = []
    for i in range(len(trainDF)):
        slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
        slopes.append(slope)
    
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(train_df, 0, 0)
print("y = " + str(m) + "x + " + str(b))

def testModel(testDF, m, b):
    checks = []
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["OverallQual"] + b)
        actual = (testDF.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 1000:
            checks.append(1)
        else:
            checks.append(0)
    return (checks.count(1) / len(checks)) * 100

print(testModel(test_df, m, b))
# Out:
# y = 28997.643171263946x + 10000
# 2.28310502283105

# %%
def trainModel(trainDF, x, y):
    slopes = []
    for i in range(len(trainDF)):
        slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
        slopes.append(slope)
    
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(train_df, 0, 0)
print("y = " + str(m) + "x + " + str(b))

def testModel(testDF, m, b):
    checks = []
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["OverallQual"] + b)
        actual = (testDF.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 2000:
            checks.append(1)
        else:
            checks.append(0)
    return (checks.count(1) / len(checks)) * 100

print(testModel(test_df, m, b))
# Out:
# y = 28997.643171263946x + 10000
# 4.337899543378995

# %%
def trainModel(trainDF, x, y):
    slopes = []
    for i in range(len(trainDF)):
        slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
        slopes.append(slope)
    
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(train_df, 0, 0)
print("y = " + str(m) + "x + " + str(b))

def testModel(testDF, m, b):
    checks = []
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["OverallQual"] + b)
        actual = (testDF.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 1000:
            checks.append(1)
        else:
            checks.append(0)
    return (checks.count(1) / len(checks)) * 100

print(testModel(test_df, m, b))

def trainModel(trainDF, x, y):
    slopes = []
    for i in range(len(trainDF)):
        slope = (trainDF.iloc[i]["SalePrice"] - y) / (trainDF.iloc[i]["OverallQual"] - x)
        slopes.append(slope)
    
    return sum(slopes)/len(slopes)
b = 10000
m = trainModel(train_df, 0, 0)
print("y = " + str(m) + "x + " + str(b))

def testModel(testDF, m, b):
    checks = []
    for i in range(len(testDF)):
        predicted = (m*testDF.iloc[i]["OverallQual"] + b)
        actual = (testDF.iloc[i]["SalePrice"])
        difference = abs(predicted - actual)
        if difference <= 5000:
            checks.append(1)
        else:
            checks.append(0)
    return (checks.count(1) / len(checks)) * 100

print(testModel(test_df, m, b))
# Out:
# y = 28997.643171263946x + 10000
# 2.28310502283105
# y = 28997.643171263946x + 10000
# 8.21917808219178
